# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 4.Crawling
#
# 스크레이핑(Scraping)이라고도 하며 웹 페이지 내의 데이터를 추출하는 것을 의미 <br>
# 데이터를 수집하기 위한 방법으로 많이 사용 <br>
# 크게 두 가지의 방법이 존재
# 1. 정적크롤링 <br>
# 정적 데이터를 수집하는 방법 <br>
# 정적 데이터란 페이지 내에 원하는 정보가 모두 들어남
#
# 2. 동적크롤링 <br>
# 동적 데이터를 수집하는 방법 <br>
# 동적 데이터란 클릭, 로그인 등의 행위를 통해 원하는 데이터에 접근 가능 <br>
#
#
# |    |정적 크롤링|동적 크롤링|
# |----|--------|--------|
# |방법 |주소 사용  |브라우저 사용|
# |수집 범위|제한적  |제한 없음|
# |속도|매우 빠름|매우
# <br>
#
# 크롤링 시 사이트에서 크롤링을 허용하는지를 반드시 확인해야 함 <br>
# robots.txt를 뒤에 붙여 확인 가능 <br>
# 강제는 아니나 이를 무시하면 추후 법률적 문제가 생길 수 있음
# ```
# www.daum.net/robots.txt
# User-agent: *
# Disallow: /
# ```
# *: All <br>
# /: All Directories

# %% [markdown]
# ## 4.1 HTTP
#
# WWW(World Wide Web, W3) 상에서 정보를 주고받을 수 있는 프로토콜 <br>
# 클라이언트와 서버 사이에 이루어지는 요청/응답 프로토콜

# %% [markdown]
# ### API
# API(Application Programming Interface) <br>
# - Application: 고유한 기능을 가진 모든 소프트웨어
# - Interface: 두 애플리케이션 간의 규약 <br>
# 이 계약은 요청과 응답을 사용하여 두 애플리케이션이 서로 통신하는 방법을 정의합니다.

# %% [markdown]
# ### REST
# REST(Representational State Transfer): 자원을 이름으로 구분하여 해당 자원의 상태를 주고받는 것 <br>
#
# REST 구성
# 1. 자원(Resource): HTTP URI
# 2. 자원에 대한 행위(Verb): HTTP Method
# 3. 자원에 대한 행위의 내용(Representations): HTTP Message Pay Load
#
#
# - HTTP URI(Uniform Resource Identifier)를 통해 자원(Resource)을 명시
# - HTTP Method(POST, GET, PUT, DELETE)를 사용하여 URI에 대한 CRUD Operation을 적용 <br>
# <br>
#
# HTTP Methods
# - GET: 자원 검색
# - POST: 자원 작성
# - PUT: 자원 업데이트
# - DELETE: 데이터 삭제
# - HEAD: 자원 검색 (GET과 유사하나 상태 줄과 헤더만 반환)
# - OPTIONS: 자원이 지원하고 있는 메소드의 취득
# - PATCH: 자원 일부 수정 (PUT과 유사하나 일부만 수정)
# - CONNECT: 자원의 터널 접속을 변경
# - TRACE: 리소스에 대한 경로를 따라 메시지 루프백 테스트를 수행
# <br>
#
# HTTP Status
# 1. 1xx(Informational): 요청 처리중
# 2. 2xx(Successful): 요청 정상 처리 <br>
# 200: 요청 성공
# 3. 3xx(Redirection): 요청을 완료하려면 추가 행동이 필요
# 4. 4xx(Client Error): 클라이언트 오류, 잘못된 문법등으로 요청을 수행할 수 없음 <br>
# 400: Bad Request, 클라이언트의 잘못된 요청으로 서버가 요청을 처리할 수 없음 <br>
# 401: Unauthorized, 해당 리소스에 대한 인증이 필요함 <br>
# 403: Forbidden, 서버가 요청을 이해했지만 승인을 거부함 <br>
# 404: Not Found, 리소스를 찾을 수 없음 <br>
# 5. 5xx(Server Error): 서버 오류

# %% [markdown]
# ### REST API
# REST의 원리를 따르는 API <br>
# ※ RESTful: REST의 원리를 따르는 시스템

# %% [markdown]
# ## 4.2 HTML
# HTML(HyperText Markup Language)은 웹 페이지 표시를 위해 개발된 지배적인 마크업 언어 <br>
# HTML은 웹 페이지 콘텐츠 안의 꺾쇠 괄호에 둘러싸인 "태그"로 되어있는 HTML 요소 형태로 작성 <br>
# HTML은 웹 브라우저와 같은 HTML 처리 장치의 행동에 영향을 주는 자바스크립트, 본문과 그 밖의 항목의 외관과 배치를 정의하는 CSS 같은 스크립트를 포함하거나 불러올 수 있음 <br>
# <br>
# HTML 선택자: HTML에서는 다수의 동일한 태그가 존재하는데 각 태그를 구별할 수 있도록 선택자를 이용
# ```html
# <div>
# 	<div>
#       <a> c </a>
#       <span> c++ </span>
#     </div>
#
#     <div>
#       <a> java </a>
#       <span> python </span>
#     </div>
# </div>
# ```
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %% [markdown]
# ## 4.3 정적크롤링

# %% [markdown]
# #### 4.3.1 라이브러리

# %% [markdown]
# ##### 4.3.1.1 requests
#
# requests: 파이썬용 http 라이브러리 <br>
# reference: https://requests.readthedocs.io/en/latest/
#
# 메소드별 사용법
# ```python
# GET: requests.get()
# POST: requests.post()
# PUT: requests.put()
# DELETE: requests.delete()
# ```
#
# ```python
# import requests
#
# requests.get("https://jsonplaceholder.typicode.com/users/1")
# ```

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://jsonplaceholder.typicode.com/users/1")
bs = BeautifulSoup(response.text, 'lxml')
bs
# Out:
# <html><body><p>{
#   "id": 1,
#   "name": "Leanne Graham",
#   "username": "Bret",
#   "email": "Sincere@april.biz",
#   "address": {
#     "street": "Kulas Light",
#     "suite": "Apt. 556",
#     "city": "Gwenborough",
#     "zipcode": "92998-3874",
#     "geo": {
#       "lat": "-37.3159",
#       "lng": "81.1496"
#     }
#   },
#   "phone": "1-770-736-8031 x56442",
#   "website": "hildegard.org",
#   "company": {
#     "name": "Romaguera-Crona",
#     "catchPhrase": "Multi-layered client-server neural-net",
#     "bs": "harness real-time e-markets"
#   }
# }</p></body></html>

# %% [markdown]
# ###### Response Body
#
# 요청이 정상적으로 처리가 되면, response body에 요청한 데이터가 담겨져 옴. <br>
# response body 크게 3가지 방식으로 읽을 수 있음 <br>
# 1. content: binary 원문을 읽음
# ```python
# response.content
# ```
# 2. text: utf-8로 인코딩 된 문자열로 읽음
# ```python
# response.text
# ```
# 3. json: 응답이 json이면 dict로 읽음
# ```python
# response.json()
# ```

# %% [markdown]
# ###### Request
#
# param: 주소에 포함된 변수를 담음<br>
# ex) https://www.naver.com/post/12345 <br>
# -> 12345 <br>
# query: 주소 바깥? 이후의 주소를 담음<br>
# ex) https://www.naver.com/post/post_id=12345&id=1 <br>
# -> 12345, 1
# body: XML, JSON 등의 데이터를 담음, 주소에서는 확인 불가<br>
# <br>
#
# requests에서는 아래와 같이 사용
# - get
# ```python
# response = requests.get("https://naver.com/post", params={"post_id": "12345", "id": "1"})
# ```
#
# - post, put: HTML 데이터 전송
# ```python
# response = requests.get("https://naver.com/post", data={"post_id": "12345", "id": "1"})
# ```
# json 형태로도 요청 가능
# ```python
# response = requests.get("https://naver.com/post", json={"post_id": "12345", "id": "1"})
# ```

# %% [markdown]
# ###### headers
#
# 일부 웹 사이트는 bot agent를 차단 <br>
# 이 경우 header의 user-agent를 아래와 같이 넘기면 해결 <br>
# ```python
# requests.get("https://naver.com/post", headers={'User-Agent': 'Mozilla 5.0'})
# ```

# %% [markdown]
# ##### 4.3.1.2 BeautifulSoup
#
# BeautifulSoup: html, xml 등으로부터 원하는 정보를 가지고 올 수 있도록 하는 라이브러리 <br>
# reference: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# response = requests.get(url)
# bs = BeautifulSoup(response.text, 'lxml')
# ```

# %% [markdown]
# ###### Parser
#
# |parser|특징|설치|속도|사용방법|
# |------|---|---|---|------|
# |html.parser||기본|보통|BeautifulSoup(html_doc, 'html.parser')|
# |lxml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'lxml')|
# |xml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'xml')|
# |html5lib|브라우저와 동일|html5lib 필요|느림|BeautifulSoup(html_doc, 'html5lib')|

# %% [markdown]
# ###### find
# 속성과 값을 이용하여 원하는 값을 찾음
#
# find: 매칭되는 값 중 상위 1개 반환
# find_all: 매칭되는 전체 반환
#
# 특정 태그 추출
# ```python
# soup.find_all('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.find_all(class_='a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.find_all('p', attrs={'class': 'a'}) # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.find_all(id='b') # b id를 갖는 값 추출
# ```
# <br>

# %% [markdown]
# ###### select
# CSS Selector로 태그를 찾아 반환 <br>
# CSS에서 HTML을 태깅하는 방법을 활용 <br>
# <br>
# select_one: 매칭되는 값 중 상위 1개 반환 <br>
# select: 매칭되는 전체 반환 <br>
# <br>
#
# 특정 태그 추출
# ```python
# soup.select('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.select('.a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.select('p.a') # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.select('#b') # b id를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 id 추출
# ```python
# soup.select('p#b') # p 태그와 b id 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 class, id 모두 추출
# ```python
# soup.select('p.a#b') # p 태그와 a 클래스 b id 모두 갖는 값 추출
# ```
# <br>
#
# 특정 태그 아래에 있는 태그 찾기
# ```python
# soup.select('div p') # div 아래 p태그가 있는 값 추출
# soup.select('div > p') # div 바로 아래 p태그가 있는 값 추출
# soup.select("div > #link") # div 바로 아래 link id가 있는 값 추출
# ```
# <br>
#
# 형제 태그 찾기
# ```python
# soup.select("#link + .sister") # link 태그와 형제 태그 중 바로 직후 1개
# soup.select("#link ~ .sister") # link 태그와 형제 태그 중 뒤에 태그 전부
# ```
# <br>
#
# 여러 태그 중 i번째 태그 추출
# ```python
# soup.select('a:nth-of-type(i)') # 추출된 a태그 중 i번째 값 반환
# ```
# <br>
# <br>
#
# 정규표현식 활용 <br>
# ```python
# soup.select('[class~=a]') # class 속성 중 a를 포함하는 태그
# soup.select('a[href]') # a 태그 중 href 속성이 존재하는 태그
# soup.select('a[href="https://www.naver.com"]') # a 태그 중 href 속성이 https://www.naver.com과 매칭되는 태그
# soup.select('a[href^="https://"]') # a 태그 중 href 속성이 https://로 시작하는 태그
# soup.select('a[href$="ac.kr"]') # a 태그 중 href 속성이 ac.kr로 끝나는 태그
# soup.select('a[href*="naver"]') # a 태그 중 href 속성 중 naver를 가지는 태그
# ```
#
# <br>
# <br>
#
# 출력
# ```python
# soup.strings # 값 반환
# soup.stripped_strings # 공백을 제거한 값 반환
# ```

# %% [markdown]
# ### 4.3.2 실습

# %% [markdown]
# ##### 예제
#
# ```html
# <div id="contents">
#     <div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = '''
<div id="contents"> 
  <div class="data1"> 
      <span class="language"> c++ </span> 
      <span class="language"> java </span> 
      <span class="language"> python </span> 
  </div> 

  <div class="data2"> 
      <a class="framework"> tensorflow </a> 
      <a class="framework"> pytorch </a> 
      <a class="framework"> spring </a> 
  </div> 
</div>
'''

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import requests
#       2 from bs4 import BeautifulSoup
# ----> 3 bs.select('div#contents')
#
# NameError: name 'bs' is not defined

# %%
bs = BeautifulSoup(response, 'lxml')

# %%
bs.select('div')[0]

# %%
bs.select('div')[1]

# %%
bs.select('div')[2]

# %%
bs.select('div')[2].select('a')

# %%
bs.select('div')[2].select('a')[0]

# %%
bs.select('div')[2].select('a')[1]

# %%
bs.select('div')[2].select('a')[2]

# %%
bs.select('div > span')

# %%
bs.select('div > a')

# %%
bs.select('div > a')[0].text.strip()

# %%
bs.select('div > a')[0].text.strip()

# %%
[tag.text.strip() for tag in bs.select('div > a')]

# %% [markdown]
# #### 네이버 뉴스

# %%
#개별 data받아오기
import requests
from bs4 import BeautifulSoup

#connection error -> user-agent처리 해야함
response = requests.get('https://n.news.naver.com/mnews/article/023/0003759424', 
                        headers={
                        'User-Agent' : 'Mozilla 5.0'
                        }) #파라미터 정보로 넣음
result = []
bs = BeautifulSoup(response.text,'lxml')
s1 = bs.select('.media_end_head_info_datestamp_bunch > span')[0]#태그정보
result.append(s1)
s2 = bs.select('.byline_p > span')[0] #인덱스로 요소값 받아오는게 아니면 반환list
result.append(s2)
print(result)


#학원수업
title = bs.select('h2#title_area > span')[0].text.strip()
time = bs.select('span.media_end_head_info_datestamp_time._ARTICLE_DATE_TIME')[0].text.strip()
author = bs.select('em.media_end_head_journalist_name')[0].text.strip()
contents = bs.select('#newsct_article')[0].text.strip()
# Out:
# [<span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2023-04-23 09:52:01">2023.04.23. 오전 9:52</span>, <span class="byline_s">실리콘밸리=김성민 특파원 dori2381@chosun.com</span>]

# %%
#여러개의 기사를 크롤링
#이후 url로접근, 개별기사 크롤링

#main페이지*(new기사 리스트)
response = requests.get('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023', 
                        headers={
                        'User-Agent' : 'Mozilla 5.0'
                        }) #파라미터 정보로 넣음
bs = BeautifulSoup(response.text,'lxml')

# %%
def get_bs_url(url):  
  response = requests.get(
                          url, 
                          headers={
                          'User-Agent' : 'Mozilla 5.0'
                          }) #파라미터 정보로 넣음
  bs = BeautifulSoup(response.text,'lxml')
  return bs

# %%
bs = get_bs_url('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023') #중복있음 -> 두개씩같음

# %%
bs.select('div.list_body.newsflash_body li dt')[1::2][0].text.strip()
# /n/n/t/t와 같은 공백문제 제거 함수 strip()
bs.select('div.list_body.newsflash_body li dt')[1::2][0].select('a')[0].attrs.get('href')


#aticle_title = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
# Out:
# 'https://n.news.naver.com/mnews/article/023/0003759295'

# %%
bs.select('div.list_body.newsflash_body li dt')[1::2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 last_page_num = int(bs.select('.pasing > strong')[0].text.strip())
#       2 bs.select('div.list_body.newsflash_body li dt')[1::2]
#
# IndexError: list index out of range

# %%
print(aticle_title)
#url_list = []
# Out:
# ['이재명, 尹 겨냥해 “살인수출”… 자유진영 28國, 우크라 군사 지원\n포토\n조선일보\n신문A1면 \n2023.04.22. 오전 3:01', '정부, LH 매입임대로 전세사기 주택 우선 매수 추진\n포토\n조선일보\n신문A1면 \n2023.04.21. 오후 6:10', '전쟁터에서 돌아와 또 살인…주민들 떨게 만든 러 죄수들', '송영길 “민주당 탈당…모든 정치적 책임 지겠다”', '“난 성공한 성폭행범” 한국계 배우 망언에…스티븐 연이 대신 사과', '조종실에 여친 부르고 “술 가져와” 요구…인도 기장의 ‘황당 갑질’', '‘尹 퇴진집회’ 간 野의원 “총선 1년, 민주당에 힘 모아달라”', '“생각 없이 샀는데 1등” “전액 아내에게”…화제된 행운의 주인공들', '수단 교민 철수 도울 군 수송기, 지부티 미군기지 도착', '‘야구 천재’ 오타니, 완벽투 과시하며 130년만의 최저 기록 달성', '“똑바로 앉으랬지” 일부러 급제동 ‘끼익’…아동학대 기소 美스쿨버스 기사', '신정훈 “난 돈 봉투 안 받았다…민주당 169명 모두 진실 고백해야”', '이 남자의 액션, 벌써 100만명 홀렸다… ‘존 윅 4′ 흥행  1위 질주', '‘마른 하늘에 날벼락’…자국 도시에 실수로 폭탄 투하한 러 전투기', '‘처짐 현상 심각’ 탄천 16개 교량 보행로 재시공', '野 “중국 막말, 尹대통령 책임도 커” 與 “중국과 한팀이냐”', 'NYT “미군 기밀문서, 우크라 침공 직후인 작년 2월부터 유출”', '검찰 기소 앞둔 신현성, 외국 재판 받는 권도형', "직원 1만명 잘려도…'빅테크 연봉킹’ 구글 CEO, 얼마 챙겼나?", '아직도 이런 개농장이? 쇠꼬챙이로 개 도살한 파주 업자', '김기현 “민주당 도덕적 파산…대장동 이어 돈 봉투 사건”', '삼성전자, 미 특허소송서 4000억원 배상 평결']

# %%
aticle_title = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]] 
#in 뒤에 list,그속에서 빼와서 표현형으로 list 추가 (전부다 넣어서 list의 길이로 for문돌리지말자)
url_list = [tag.select('a')[0].get('href') for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
print(url_list)
#왜 [0]이들어가지?
# Out:
# ['https://n.news.naver.com/mnews/article/023/0003759297', 'https://n.news.naver.com/mnews/article/023/0003759296', 'https://n.news.naver.com/mnews/article/023/0003759295', 'https://n.news.naver.com/mnews/article/023/0003759294', 'https://n.news.naver.com/mnews/article/023/0003759292', 'https://n.news.naver.com/mnews/article/023/0003759291', 'https://n.news.naver.com/mnews/article/023/0003759290', 'https://n.news.naver.com/mnews/article/023/0003759289']

# %%
news = pd.DataFrame({
    'title' : titles, #수업때 쓰는 변수임
    'url' : urls
})

# %% [markdown]
# ## 페이지 전체

# %%
#DateFrmae()파라미터 columns알아보기

# %%
total_news = pd.DataFrame(columns=['title','url'])
for page in range(1, 8):  
  url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=023&date=20230422&page={page}'
  bs = get_bs_url(url)
  titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]] 
  urls = [tag.select('a')[0].get('href') for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
  
  news = pd.DataFrame({
    'title' : titles,
    'url' : urls
  })
  total_news = pd.concat([total_news, news])

# %%
  
  total_news
# Out:
#                                                 title  \
# 0   이재명, 尹 겨냥해 “살인수출”… 자유진영 28國, 우크라 군사 지원\n포토\n조선...
# 1   정부, LH 매입임대로 전세사기 주택 우선 매수 추진\n포토\n조선일보\n신문A1면...
# 2                      전쟁터에서 돌아와 또 살인…주민들 떨게 만든 러 죄수들
# 3                          송영길 “민주당 탈당…모든 정치적 책임 지겠다”
# 4                “난 성공한 성폭행범” 한국계 배우 망언에…스티븐 연이 대신 사과
# ..                                                ...
# 3             전세사기꾼 7000억 사업 따낼 때, 인천 공무원이 강원도 옮겨가 총괄
# 4
# 5
# 6
# 7
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# 5   https://n.news.naver.com/mnews/article/023/000...
# 6   https://n.news.naver.com/mnews/article/023/000...
# 7   https://n.news.naver.com/mnews/article/023/000...
#
# [121 rows x 2 columns]

# %% [markdown]
# ### 특정날짜 범위

# %%
ds.
pd.date_range('20230401','20230423').strftime("%Y%m%d") #strftime알아보기
# Out:
# Index(['20230401', '20230402', '20230403', '20230404', '20230405', '20230406',
#        '20230407', '20230408', '20230409', '20230410', '20230411', '20230412',
#        '20230413', '20230414', '20230415', '20230416', '20230417', '20230418',
#        '20230419', '20230420', '20230421', '20230422', '20230423'],
#       dtype='object')

# %%
last_page_num = bs.select('.pasing > strong')[0].text.strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 last_page_num = bs.select('.pasing > strong')[0].text.strip()
#
# IndexError: list index out of range

# %%
bs
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="조선일보 언론사홈" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=023" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="조선일보 언론사홈" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="언론사 주요 뉴스와 속보를 만나볼 수 있습니다." name="twitter:description"/>
# <title>조선일보 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='sec';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.press';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Sun Apr 23 13:01:48 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>04</strong>.<strong>23</strong><span class="day">(일)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_prs.home)" href="/main/officeList.naver">언론사 뉴스</a></h2>
# <ul class="nav">
# <li class="on"><a class="nclicks(lmn_prs.tog)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=032">종합 <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lmn_prs.bro)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=421">방송/통신 </a></li>
# <li><a class="nclicks(lmn_prs.eco)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=009">경제 </a></li>
# <li><a class="nclicks(lmn_prs.int)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=079">인터넷 </a></li>
# <li><a class="nclicks(lmn_prs.sci)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=138">IT </a></li>
# <li><a class="nclicks(lmn_prs.pho)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=348">포토 </a></li>
# <li><a class="nclicks(lmn_prs.mag)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=665">매거진 </a></li>
# <li><a class="nclicks(lmn_prs.pro)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=127">전문지 </a></li>
# <li><a class="nclicks(lmn_prs.reg)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=654">지역 </a></li>
# </ul>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_header newsflash_header2">
# <h3>종합</h3>
# <div class="topbox_type4">
# <div>
# <ul class="massmedia">
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=032">경향신문</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=005">국민일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=020">동아일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=021">문화일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=081">서울신문</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=022">세계일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="visit on nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=023">조선일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=025">중앙일보</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=028">한겨레</a>
# <i class="picon">신문</i>
# </li>
# <li>
# <a class="nclicks(cnt_press)" href="/main/list.naver?mode=LPOD&amp;mid=sec&amp;oid=469">한국일보</a>
# <i class="picon">신문</i>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="list_body newsflash_body">
# <div class="newsflash_header3">
# <h3>조선일보</h3>
# <div class="view_type">
# <a class="newsp nclicks(fls.vtype)" href="list.naver;jsessionid=CF6E46B6DFB98D53060ED867C486D9FB?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=paper&amp;date=20230401" title="신문에 게재된 기사만 보실 수 있습니다.">신문게재기사만</a><span class="bar">|</span>
# <a class="tit_off nclicks(fls.vtype)" href="list.naver;jsessionid=CF6E46B6DFB98D53060ED867C486D9FB?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=title&amp;date=20230401">제목형</a>
# <a class="sum_on nclicks(fls.vtype)" href="list.naver;jsessionid=CF6E46B6DFB98D53060ED867C486D9FB?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=summary&amp;date=20230401">요약형</a>
# <a class="photo_off nclicks(fls.vtype)" href="list.naver;jsessionid=CF6E46B6DFB98D53060ED867C486D9FB?mode=LPOD&amp;mid=sec&amp;oid=023&amp;listType=photo&amp;type=3&amp;date=20230401">포토만</a>
# </div>
# </div>
# <ul class="type06_headline">
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755284">
# <img alt="하얗게 변한 고래섬... 저게 다 새똥 때문이라고? [아무튼, 주말]" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755284.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755284">
# 								 하얗게 변한 고래섬... 저게 다 새똥 때문이라고? [아무튼, 주말]
# 								</a>
# </dt>
# <dd>
# <span class="lede">대전 대청호 안에 있는 작은 무인도. 생김새가 고래를 닮아서 이름이 ‘고래섬’인 이곳이 눈이라도 쌓인 듯 하얗게 변해 있다. 얼 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 B8면의 기사입니다."><i class="picon">신문</i>B8면 </span>
# <span class="date">2023.04.01. 오전 3:01</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755283">
# <img alt="야외 바비큐 환상은 없다… 그래도 시골에서 살고 싶은 이유" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755283.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755283">
# 								 야외 바비큐 환상은 없다… 그래도 시골에서 살고 싶은 이유
# 								</a>
# </dt>
# <dd>
# <span class="lede">은퇴 후엔 시골에 살 생각이다. 흔히 말하는 전원주택에 대한 환상 같은 건 없다. 그냥 공기 좋은 시골에 집을 지어 살고 싶다. …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 B4면의 기사입니다."><i class="picon">신문</i>B4면 </span>
# <span class="date">2023.04.01. 오전 3:01</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755282">
# <img alt="러·중동·브라질… 中위안화 결제국 늘어난다" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755282.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755282">
# 								 러·중동·브라질… 中위안화 결제국 늘어난다
# 								</a>
# </dt>
# <dd>
# <span class="lede">中, 달러 패권에 도전 가시화 “위안화 출해(出海·국제화)의 상징적 사건” 지난 27일 사우디아라비아 국영 석유기업 아람코가 중 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A14면의 기사입니다."><i class="picon">신문</i>A14면 </span>
# <span class="date">2023.04.01. 오전 1:27</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755281">
# <img alt="“티라노사우루스 이빨, 입술에 덮여있었다”" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755281.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755281">
# 								 “티라노사우루스 이빨, 입술에 덮여있었다”
# 								</a>
# </dt>
# <dd>
# <span class="lede">영화 ‘쥬라기 공원’ 속 티라노사우루스는 악어처럼 입을 다물어도 날카롭고 큰 이빨이 드러난 모습이다. 자연사 박물관의 티라노사우 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A14면의 기사입니다."><i class="picon">신문</i>A14면 </span>
# <span class="date">2023.04.01. 오전 12:41</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755280">
# <img alt="봄 만끽하기도 전에 초여름... 오늘 서울 낮 26도" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755280.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755280">
# 								 봄 만끽하기도 전에 초여름... 오늘 서울 낮 26도
# 								</a>
# </dt>
# <dd>
# <span class="lede">식목일쯤 세찬 비온 뒤 ‘벚꽃엔딩’ 기상청은 주말인 1~2일 우리나라가 고기압 영향권에 들면서 전국이 대체로 맑겠고, 한낮은 초 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A10면의 기사입니다."><i class="picon">신문</i>A10면 </span>
# <span class="date">2023.04.01. 오전 12:35</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755279">
# <img alt="돌고래 낮잠 방해한 죄… 하와이 해변서 관광객 33명 고발된 이유" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755279.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755279">
# 								 돌고래 낮잠 방해한 죄… 하와이 해변서 관광객 33명 고발된 이유
# 								</a>
# </dt>
# <dd>
# <span class="lede">미국 하와이 당국이 단체 수영으로 야생 돌고래 떼를 따라다니며 괴롭힌 관광객 33명을 고발했다. AP통신, BBC 등에 따르면  …</span>
# <span class="writing">조선일보</span>
# <span class="date">2023.04.01. 오전 12:34</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755278">
# <img alt="트럼프 “수갑 채워 데려가라”... 다시 두쪽 나는 美, 경찰은 비상대기령" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755278.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755278">
# 								 트럼프 “수갑 채워 데려가라”... 다시 두쪽 나는 美, 경찰은 비상대기령
# 								</a>
# </dt>
# <dd>
# <span class="lede">‘성추문 입막음’ 관련 전격 기소 전·현 대통령 기소, 美건국 후 처음 트럼프 “정치 박해” 지지층 선동 도널드 트럼프 전 미국 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A1면의 기사입니다."><i class="picon">신문</i>A1면 </span>
# <span class="date">2023.04.01. 오전 12:24</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755277">
# <img alt="폰·태블릿 많이 본 10살 추적했더니… 2년 후 ‘이 병’ 위험 높았다" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755277.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755277">
# 								 폰·태블릿 많이 본 10살 추적했더니… 2년 후 ‘이 병’ 위험 높았다
# 								</a>
# </dt>
# <dd>
# <span class="lede">스마트폰·태블릿·PC 등 온라인 사용이 잦은 아이들에게 우울과 불안 같은 ‘기분장애’(mood disorder)가 나타날 위험이 …</span>
# <span class="writing">조선일보</span>
# <span class="date">2023.04.01. 오전 12:08</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755276">
# <img alt="[특파원 리포트] 가사도우미가 ‘현대판 노예’?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755276.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755276">
# 								 [특파원 리포트] 가사도우미가 ‘현대판 노예’?
# 								</a>
# </dt>
# <dd>
# <span class="lede">“외국인 가사도우미가 ‘현대판 노예’라는 말을 어떻게 생각하나요?” 지난달 29일 싱가포르에서 일하는 외국인 가사도우미들을 인터 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A26면의 기사입니다."><i class="picon">신문</i>A26면 </span>
# <span class="date">2023.04.01. 오전 12:01</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755275">
# <img alt="[터치! 코리아] ‘딸배’라 불리는 사나이" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755275.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755275">
# 								 [터치! 코리아] ‘딸배’라 불리는 사나이
# 								</a>
# </dt>
# <dd>
# <span class="lede">도로의 무법자 ‘딸배’ 확산 몰래 신고하는 ‘딸배헌터’도 시민 돕는 정의의 기사처럼 이제는 법 지키며 달립시다 우리나라 국조(國 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A27면의 기사입니다."><i class="picon">신문</i>A27면 </span>
# <span class="date">2023.04.01. 오전 12:01</span>
# </dd>
# </dl>
# </li>
# </ul>
# <ul class="type06">
# <li>
# <dl>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755274">
# 								 [백영옥의 말과 글] [297] 걱정을 줄이는 법
# 								</a>
# </dt>
# <dd>
# <span class="lede">걱정이 많을 때, 드라마나 영화를 보면 왜 휴식하는 느낌이 들까. ‘아무 생각 없이’ 집중하기 때문이라고 생각하겠지만 오히려 영 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A26면의 기사입니다."><i class="picon">신문</i>A26면 </span>
# <span class="date">2023.04.01. 오전 12:01</span>
# </dd>
# </dl>
# </li>
# <li>
# <dl>
# <dt class="photo">
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755273">
# <img alt="[朝鮮칼럼 The Column] ‘김명수’가 ‘김명수2′를 추천한다고?" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_106x72.png';" src="https://imgnews.pstatic.net/image/origin/023/2023/04/01/3755273.jpg?type=nf106_72" width="106"/>
# </a>
# </dt>
# <dt>
# <a class="nclicks(cnt_flashart)" href="https://n.news.naver.com/mnews/article/023/0003755273">
# 								 [朝鮮칼럼 The Column] ‘김명수’가 ‘김명수2′를 추천한다고?
# 								</a>
# </dt>
# <dd>
# <span class="lede">민주당에서 대법원장이 대법원장후보자추천위원회를 구성해 후임자를 추천하게 하는 법안을 냈다는 기사를 접하니 웃음이 나왔다. 김명수 …</span>
# <span class="writing">조선일보</span>
# <span class="newspaper_info" title="신문에 게재되었으며 A26면의 기사입니다."><i class="picon">신문</i>A26면 </span>
# <span class="date">2023.04.01. 오전 12:01</span>
# </dd>
# </dl>
# </li>
# </ul>
# </div>
# <div class="paging">
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=1">1</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=2">2</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=3">3</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=4">4</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=5">5</a>
# <a class="nclicks(fls.page)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230401&amp;page=6">6</a>
# <strong>7</strong>
# </div>
# <h4 class="blind">뉴스 이전날짜 더보기 링크모음</h4>
# <div class="pagenavi_day">
# <a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230403">4월3일(월)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230402">4월2일(일)</a><span class="devidebar">·</span><span class="viewday">4월1일(토)</span><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230331">3월31일(금)</a><span class="devidebar">·</span><a class="nclicks(fls.date)" href="?mode=LPOD&amp;mid=sec&amp;oid=023&amp;date=20230330">3월30일(목)</a></div>
# <script type="text/javascript">
# window.onload = function() {
# 	var selected_item = jindo.$('_');
# 	if (selected_item != null) {
# 		selected_item.className = "highlight";
# 		news.section.ScrollingManager.scroll('');
# 	}
# }
# news.section.MainIssueCollectManager.init({
# 	mediaOneDomain : 'https://n.news.naver.com'
# });
# news.util.CommentListCountManager.view();
# </script>
# </div>
# </td>
# <td class="aside">
# <div class="aside">
# <div class="section _officeTopRanking1087479">
# <h4>언론사별 가장 많이 본 뉴스</h4>
# <button class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton" type="button">안내</button>
# <div class="section_info_layer _rankingInfoLayer" style="display: none">각 언론사의 가장 많이 본 기사 1건을 제공합니다. <button class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')" type="button"><span>닫기</span></button></div>
# <p class="section_sub_txt">오전 11시~오후 12시까지 집계한 결과입니다.</p>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/032/0003218981?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/032/2023/04/23/3218981.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/032/0003218981?ntype=RANKING&amp;sid=001">청도 캠핑장서 50대 남성 숨진채 발견…일산화탄소 중독 추 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=032"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png" width="16"/></span>경향신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/421/0006763721?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/421/2023/04/23/6763721.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/421/0006763721?ntype=RANKING&amp;sid=001">'12년 학폭' 표예림, 극단선택 시도…"가해자 내용증명에 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=421"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/421/2021/02/09/logo_421_56_20210209173713.jpg" width="16"/></span>뉴스1</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000340314?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/437/2023/04/22/340314.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000340314?ntype=RANKING&amp;sid=001">유행처럼 번진 미 '기아 보이즈' 챌린지…현대·기아차 리콜 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=437"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png" width="16"/></span>JTBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0001052555?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/055/2023/04/23/1052555.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0001052555?ntype=RANKING&amp;sid=001">작년 로또 1등 당첨자 129명에게 물었다…"복권 왜 샀나 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=055"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" width="16"/></span>SBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/016/0002133846?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/016/2023/04/23/2133846.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/016/0002133846?ntype=RANKING&amp;sid=001">“컵라면, 전자레인지 돌렸다가 뒤집혔다” 왜 이런 일이?  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=016"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg" width="16"/></span>헤럴드경제</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList5" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/020/0003493049?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/020/2023/04/22/3493049.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/020/0003493049?ntype=RANKING&amp;sid=001">‘피지컬100’의 이 몸짱 독일인, 사실은 글로벌 컨설팅기 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=020"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg" width="16"/></span>동아일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003759423?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/023/2023/04/23/3759423.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003759423?ntype=RANKING&amp;sid=001">“밤 자르게 칼 좀 달라”더니... 모르는 옆 테이블 손님 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=023"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" width="16"/></span>조선일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/028/0002636911?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/028/2023/04/23/2636911.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/028/0002636911?ntype=RANKING&amp;sid=001">중, 윤 대통령 ‘대만’ 발언에 “강한 불만”…한국대사 불 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=028"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2018/08/01/logo_028_56_20180801163801.png" width="16"/></span>한겨레</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005120292?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/009/2023/04/23/5120292.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005120292?ntype=RANKING&amp;sid=001">“여보 미안, 필라테스 학원 카드 긁었다 150만원 날렸어 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=009"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png" width="16"/></span>매일경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/003/0011818446?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/003/2023/04/23/11818446.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/003/0011818446?ntype=RANKING&amp;sid=001">"'학폭 피해' 표예림씨, 극단적 선택 시도"</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=003"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/003/2022/02/21/logo_003_56_20220221152351.jpg" width="16"/></span>뉴시스</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList10" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/025/0003274963?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/025/2023/04/23/3274963.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/025/0003274963?ntype=RANKING&amp;sid=001">"4월에 꺾으면 맛 최고"…1㎏ 13만원 '산에서 나는 소 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=025"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/20/logo_025_56_20210820165911.png" width="16"/></span>중앙일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/015/0004835952?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/015/2023/04/23/4835952.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/015/0004835952?ntype=RANKING&amp;sid=001">"3주 만에 7.5kg 감량"…할리우드 '기적의 다이어트' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=015"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2020/08/11/logo_015_56_20200811194037.png" width="16"/></span>한국경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001876587?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/052/2023/04/23/1876587.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001876587?ntype=RANKING&amp;sid=001">군인·공무원까지 전국 시위...사법개혁안 폐지 촉구</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=052"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png" width="16"/></span>YTN</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004182066?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/011/2023/04/23/4182066.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004182066?ntype=RANKING&amp;sid=001">학폭 가해자의 2차 가해…표예림, 극단적 선택 시도</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=011"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" width="16"/></span>서울경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/087/0000965858?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/087/2023/04/23/965858.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/087/0000965858?ntype=RANKING&amp;sid=001">설악산서 사진 찍던 40대 등산객 5m 아래 추락해 사망</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=087"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png" width="16"/></span>강원일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList15" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/215/0001097123?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/215/2023/04/23/1097123.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/215/0001097123?ntype=RANKING&amp;sid=001">"안 오른게 없다더니 이것마저"…11년來 상승폭 최대</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=215"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2020/08/12/logo_215_56_20200812134433.png" width="16"/></span>한국경제TV</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/214/0001268168?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/214/2023/04/23/1268168.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/214/0001268168?ntype=RANKING&amp;sid=001">미국은 배터리 새판 짜는데‥포드·테슬라는 왜 중국과 손잡나 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=214"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/214/2020/06/30/logo_214_56_20200630111130.png" width="16"/></span>MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001603151?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/005/2023/04/23/1603151.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001603151?ntype=RANKING&amp;sid=001">매일유업이 1년에 2번 공장 가동을 멈추는 이유는…</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=005"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" width="16"/></span>국민일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/079/0003762342?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/079/2023/04/23/3762342.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/079/0003762342?ntype=RANKING&amp;sid=001">JMS 정명석-외국 여신도 연결 통역사 고백…"성폭력 직접 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=079"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/079/2018/07/18/logo_079_56_20180718152918.png" width="16"/></span>노컷뉴스</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/021/0002568048?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/021/2023/04/23/2568048.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/021/0002568048?ntype=RANKING&amp;sid=001">교대 나와도 교사 되기 어렵다…지난해 2명 중 1명은 임용 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=021"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/021/2022/08/04/logo_021_56_20220804125306.png" width="16"/></span>문화일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList20" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/277/0005249291?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/277/2023/04/23/5249291.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/277/0005249291?ntype=RANKING&amp;sid=001">"괴물폭염이 한국 덮친다"…역대급 '4월 폭염'에 펄펄 끓 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=277"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png" width="16"/></span>아시아경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005469839?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/018/2023/04/23/5469839.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005469839?ntype=RANKING&amp;sid=001">산 속 '단독주택 라이프' 김대호 아나운서 집은 어디?[누 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=018"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2018/07/18/logo_018_56_20180718152418.png" width="16"/></span>이데일리</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003355792?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/081/2023/04/23/3355792.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003355792?ntype=RANKING&amp;sid=001">강제로 옷 벗겨 민감한 부위 생중계한 10대들… 檢, 중형 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=081"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png" width="16"/></span>서울신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/422/0000595167?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/422/2023/04/22/595167.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/422/0000595167?ntype=RANKING&amp;sid=001">'전면 수출금지' 검토…러 '세계경제 폭망' 경고</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=422"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/11/29/logo_422_56_20191129165529.jpg" width="16"/></span>연합뉴스TV</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000895847?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/366/2023/04/23/895847.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000895847?ntype=RANKING&amp;sid=001">”화성사업장까지 걸어서 8분”… ‘동탄 전세사기’ 삼성전자 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=366"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png" width="16"/></span>조선비즈</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList25" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/056/0011471053?ntype=RANKING&amp;sid=001">
# ...
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/658/2023/04/23/38965.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000038965?ntype=RANKING&amp;sid=001">창원 마산 굿당 불…야산 번져 2시간여만 진화</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=658"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" width="16"/></span>국제신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000010916?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/04/22/10916.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000010916?ntype=RANKING&amp;sid=001">'필로폰 투약했던 14살 여중생'.. "같은 반 2명과 함 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000839?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/04/23/839.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000839?ntype=RANKING&amp;sid=001">52시간이든 69시간이든 한가할 때도 바쁜 사람들 [視리즈 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044732?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/353/2023/04/22/44732.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/353/0000044732?ntype=RANKING&amp;sid=001">평생 한 여자만 그렸는데 사이는 나빴다고? 에드워드 호퍼의 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=353"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/353/2018/09/20/logo_353_56_20180920154420.png" width="16"/></span>중앙SUNDAY</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018558?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/04/22/18558.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018558?ntype=RANKING&amp;sid=001">김 없이 신선함 가득 ‘오트밀 김밥’[주말&amp;]</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087479");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/020/0003493069?sid=100" title="민주 “송영길 탈당·귀국 결정 존중”…與 “꼬리 자르기 행보”">민주 “송영길 탈당·귀국 결정 존중”…與 “꼬리 자르기 행보”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013897342?sid=100" title='與 "송영길 탈당은 꼬리자르기…핑계·꼼수 이재명 데칼코마니"'>與 "송영길 탈당은 꼬리자르기…핑계·꼼수 이재명 데칼코마니"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005469887?sid=100" title="김기현 “민주당, 아직도 사대주의적 속국인식 빠져”">김기현 “민주당, 아직도 사대주의적 속국인식 빠져”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/023/0003759430?sid=104" title="中관영매체 “韓 외교 국격 산산조각”… 尹대만 발언 연일 비난">中관영매체 “韓 외교 국격 산산조각”… 尹대만 발언 연일 비난</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005469958?sid=104" title="“日 원전 오염수 방류, 이르면 7월부터…공사 막바지”">“日 원전 오염수 방류, 이르면 7월부터…공사 막바지”</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013897311?sid=101" title="SK온, 美 '에디슨 어워즈' 수상…&quot;글로벌 배터리 제조사 최초&quot;">SK온, 美 '에디슨 어워즈' 수상…"글로벌 배터리 제조사 최초"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/658/0000038970?sid=101" title="'옷값도 천정부지'…부산 의류·신발 물가 11년 만에 최고">'옷값도 천정부지'…부산 의류·신발 물가 11년 만에 최고</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005469956?sid=101" title="[단독]인천 전세사기 경매물건, 절반 이상이 대부업체 소유">[단독]인천 전세사기 경매물건, 절반 이상이 대부업체 소유</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011818768?sid=105" title='올해 정보보호 공시 의무 기업 655개…"대기업·통신사·SNS 등 대상"'>올해 정보보호 공시 의무 기업 655개…"대기업·통신사·SNS 등 대상"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/015/0004835986?sid=105" title='3만원대 5G요금제 나오나…정부 "최저요금 더 낮춰야"'>3만원대 5G요금제 나오나…정부 "최저요금 더 낮춰야"</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/005/0001603187?sid=102" title="학폭 폭로 표예림씨, 극단 선택 시도…“2차 가해로 고통”">학폭 폭로 표예림씨, 극단 선택 시도…“2차 가해로 고통”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/005/0001603167?sid=102" title="자전거로 퇴근 중 신호위반 ‘쾅’…“산업재해” 소송냈지만">자전거로 퇴근 중 신호위반 ‘쾅’…“산업재해” 소송냈지만</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005120325?sid=102" title="한동훈 “마약이 피자 한판값 됐다, 文정부가 검찰 손발 자른탓”">한동훈 “마약이 피자 한판값 됐다, 文정부가 검찰 손발 자른탓”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/119/0002705517?sid=103" title="기아, 밀라노서 디자인 경쟁력 전 세계에 알렸다">기아, 밀라노서 디자인 경쟁력 전 세계에 알렸다</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/449/0000248202?sid=103" title="미세먼지 나쁨, 대기 건조...낮 최고 15~22도">미세먼지 나쁨, 대기 건조...낮 최고 15~22도</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://factcheck.snu.ac.kr/" target="_blank"> <img alt="온라인 허위정보, 팩트체크 어떻게 확인할까요" src="https://imgnews.pstatic.net/image/upload/item/2020/02/05/175955946_%2540banner_300X80_pc.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183022480_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
# new news.flash.SubsectionLayerManager('n.f.subsection.layer');
#
#
# new MyFeed()
#     .init({
#         sMyFeedUrl: 'https://me.naver.com/tab/feed/news.nhn',
#         apiUrlMap: {
#             'check': 'https://apis.naver.com/newsweb/media/subscribedChannels?hasFollowerCount=true',
#             'follow': 'https://apis.naver.com/newsweb/media/doSubscribe',
#             'unfollow': 'https://apis.naver.com/newsweb/media/cancelSubscribe'
#         }
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
from tqdm import tqdm #?


total_news = pd.DataFrame(columns=['date','oid','title','url'])

for oid in tqdm(['023','028']):
  for date in pd.date_range('20230401','20230423'):
    date = date.strftime("%Y%m%d")
    
    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page=10000'
    bs = get_bs_url(url)
    last_page_num = int(bs.select('.paging > strong')[0].text.strip())

    for page in range(1, last_page_num+1):  
      url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page={page}'
      bs = get_bs_url(url)
      titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]] 
      urls = [tag.select('a')[0].get('href') for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
      
      news = pd.DataFrame({
        'date' : date,
        'oid' : oid,
        'title' : titles,
        'url' : urls   
      })
      total_news = pd.concat([total_news, news])
# Out:
# 100%|██████████| 2/2 [01:22<00:00, 41.43s/it]

# %%
len(total_news)
# Out:
# 6763

# %% [markdown]
# # 네이버 뉴스 크롤러

# %%
def naver_news_crawler(oids, start_date, end_date):
  total_news = pd.DataFrame(columns=['date','oid','title','url'])

  for oid in oids:
    for date in pd.date_range(start_date, end_date):
      date = date.strftime("%Y%m%d")
      
      url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page=10000'
      bs = get_bs_url(url)
      last_page_num = int(bs.select('.paging > strong')[0].text.strip())

      for page in range(1, last_page_num+1):  
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid={oid}&date={date}&page={page}'
        bs = get_bs_url(url)
        titles = [tag.text.strip() for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]] 
        urls = [tag.select('a')[0].get('href') for tag in bs.select('div.list_body.newsflash_body li dt')[1::2]]
        
        news = pd.DataFrame({
          'date' : date,
          'oid' : oid,
          'title' : titles,
          'url' : urls   
        })
        total_news = pd.concat([total_news, news])
  return total_news

# %%
naver_news_crawler(['023','025','028'],'20230421','20230423')
# Out:
#         date  oid                                              title  \
# 0   20230421  023  [단독] ‘문재인 탈원전’, 한전에 26조 손실 떠안겼다\n포토\n조선일보\n신문A...
# 1   20230421  023  중국 “대만 말참견 말라” 한국 “국격 의심돼”\n조선일보\n신문A1면 \n2023...
# 2   20230421  023                    엄지발가락 물어뜯은 불도그… 주인은 “땡큐”, 무슨 일?
# 3   20230421  023          [반론보도] 「“尹 퇴진이 추모다” 北, 민노총에 시위구호까지 지령」 관련
# 4   20230421  023          인천 전세 사기꾼 “함께 부자 되자”... 동해 사업 거론하며 피해자 회유
# ..       ...  ...                                                ...
# 16  20230423  028                                     허구와 착시, 그리고 진실
# 17  20230423  028                       자전거 퇴근하다 신호위반 사고…법원 “산재 아니다”
# 18  20230423  028                      인공지능 ‘빛의 질주’…따라갈 것인가, 성찰할 것인가
# 19  20230423  028                    김성회 전 비서관, ‘MBC가 초상권 침해’ 손배소 패소
# 0   20230423  028                      돈봉투 의혹은 ‘송영길 사건’ 아니라 ‘민주당 사건’
#
#                                                   url
# 0   https://n.news.naver.com/mnews/article/023/000...
# 1   https://n.news.naver.com/mnews/article/023/000...
# 2   https://n.news.naver.com/mnews/article/023/000...
# 3   https://n.news.naver.com/mnews/article/023/000...
# 4   https://n.news.naver.com/mnews/article/023/000...
# ..                                                ...
# 16  https://n.news.naver.com/mnews/article/028/000...
# 17  https://n.news.naver.com/mnews/article/028/000...
# 18  https://n.news.naver.com/mnews/article/028/000...
# 19  https://n.news.naver.com/mnews/article/028/000...
# 0   https://n.news.naver.com/mnews/article/028/000...
#
# [847 rows x 4 columns]

# %% [markdown]
# #### 네이버 증권

# %% [markdown]
# #### 다음 증권
